# %%
# Cell 1: Setup
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_cleaning import FraudDataCleaner
from src.eda import FraudEDA
# %matplotlib inline

# %%
# Cell 2: Load and Clean
cleaner = FraudDataCleaner(r'C:\Users\admin\fraud-detection-week5\data\raw\Fraud_Data.csv', 'C:\Users\admin\fraud-detection-week5\data\raw\IpAddress_to_Country.csv')
fraud_df, ip_df = cleaner.clean_pipeline()

# %%
# Cell 3: EDA
eda = FraudEDA(fraud_df)
class_info = eda.comprehensive_eda()

# %%
# Cell 4: Save Results
fraud_df.to_csv(r'C:/Users/admin/fraud-detection-week5/data/processed/processed/cleaned_fraud_data.csv', index=False)
